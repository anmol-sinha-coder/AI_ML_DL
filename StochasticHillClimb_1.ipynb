# %% [markdown]
# Stochastic Hill Climbing

# %%
import numpy as np
import random;

#The PEAS
#Time, Speed, Fuel, Distance
#Init_solution = [10, 100, 25, 10];
#Init_solution = [2,10,5,100]
#Init_solution=None
#Init_solution = [0, 0, 0, 0];


Iterations = 0
max_itr=100 #10000
Final_solution = None

#Contains an objective vector of attributes to be optimized and the cost associated with the objectives
class Solu_space: # solution space
    def __init__(self):
        self.obj_vector = None
        self.cost = None


    def setObj_vector(self, val):
        self.obj_vector = val

    def setCost(self, cost):
        self.cost = cost

    def getAttr(self):
        return {'Time, Speed, Fuel, Distance': self.obj_vector, 'Cost': self.cost }
    #Time,speed,fuel,distance



# Function for calculating the cost - The evaluation function
def calc_cost(objVector):
    #print("Inside calc cost")
    #print(objVector)
    #objVector=objVector
    cost = round((objVector[0]   + objVector[1]  + objVector[2] - objVector[3]),2)
   # cost = objVector[0]   + objVector[1]  + (objVector[2]/objVector[3])
    #print("Cost"+str(cost))
    return abs(cost) # Measuring which combination is better

# Function to generate new solution in the neighborhood - Random
def gen_new_solution():
    distance_step=0
    speed_step=random.randint(10,100)
    time_step=round((random.randint(1,100))/60,2)
    #distance_step=random.randint(1,500)
    try:
        distance_step=random.randint(1,round(speed_step*time_step,2))
    except:
        pass
    fuel_step=random.randint(1,25)
                 #Time, Speed, Fuel, Distance
    objVector=[time_step,speed_step,fuel_step,distance_step]
    #print("new solution: "+str(objVector))
    return objVector

def Hill_Climb(objVector):
    #print("Inside Hill_Climb(objVector)")
    #print (objVector)
    soln_space = Solu_space()
    soln_space.setObj_vector(objVector)
    oldCost = calc_cost(objVector);
    soln_space.setCost(oldCost)

    #print("old objvector")
    #print(soln_space.obj_vector)
    #print("Old cost")
    #print(soln_space.cost)
    newobjVector = gen_new_solution()
    #print("new object vector")
    #print(newobjVector)
    newcost= calc_cost(newobjVector)
    #print("new cost")
    #print(newcost)

    if(newcost < oldCost):
        soln_space.setObj_vector(newobjVector)
        soln_space.setCost(newcost)
        #print(soln_space.obj_vector)
        #print(soln_space.cost)
        print(str(soln_space.getAttr()))
        return soln_space.obj_vector
    print(str(soln_space.getAttr()))
    return soln_space.obj_vector



def stopit():
    globals()
    cost=calc_cost(Final_solution)
    if cost == 0:
        return True
    if Iterations == max_itr:
        return True
    else:
        return False

Init_soln=[random.randint(1,10),random.randint(1,100),random.randint(1,25),random.randint(1,500)]
Final_solution= Hill_Climb(Init_soln)
print(Final_solution)
while not stopit():
    solution=Final_solution
    Final_solution=Hill_Climb(solution)
    #print("Solution")
    #print("Time,Speed,Fuel,Distance Covered")
    #print(solution)
    #print(str(Final_solution[0])+ "  Hrs  " +str(Final_solution[1])+ "  Km/Hr  " + str(Final_solution[2]) + " Litres " + str(Final_solution[3]) + " Kms")
    #print("Cost" + str(calc_cost(Final_solution)))

    #print(calc_cost(Final_solution))
    print("Iteration no: "+str(Iterations))
    Iterations+=1
print("Solution")
print(str(Final_solution[0])+ "  Hrs  " +str(Final_solution[1])+ "  Km/Hr  " + str(Final_solution[2]) + " Litres " + str(Final_solution[3]) + " Kms")
print("Cost" + str(calc_cost(Final_solution)))
# Out:
# {'Time, Speed, Fuel, Distance': [1.45, 85, 6, 0], 'Cost': 92.45}
# [1.45, 85, 6, 0]
# {'Time, Speed, Fuel, Distance': [1.45, 85, 6, 0], 'Cost': 92.45}
# Iteration no: 0
# {'Time, Speed, Fuel, Distance': [1.42, 42, 20, 0], 'Cost': 63.42}
# Iteration no: 1
# {'Time, Speed, Fuel, Distance': [1.42, 42, 20, 0], 'Cost': 63.42}
# Iteration no: 2
# {'Time, Speed, Fuel, Distance': [1.42, 42, 20, 0], 'Cost': 63.42}
# Iteration no: 3
# {'Time, Speed, Fuel, Distance': [0.97, 18, 2, 0], 'Cost': 20.97}
# Iteration no: 4
# {'Time, Speed, Fuel, Distance': [0.97, 18, 2, 0], 'Cost': 20.97}
# Iteration no: 5
# {'Time, Speed, Fuel, Distance': [0.97, 18, 2, 0], 'Cost': 20.97}
# Iteration no: 6
# {'Time, Speed, Fuel, Distance': [0.97, 18, 2, 0], 'Cost': 20.97}
# Iteration no: 7
# {'Time, Speed, Fuel, Distance': [0.97, 18, 2, 0], 'Cost': 20.97}
# Iteration no: 8
# {'Time, Speed, Fuel, Distance': [0.97, 18, 2, 0], 'Cost': 20.97}
# Iteration no: 9
# {'Time, Speed, Fuel, Distance': [0.97, 18, 2, 0], 'Cost': 20.97}
# Iteration no: 10
# {'Time, Speed, Fuel, Distance': [0.97, 18, 2, 0], 'Cost': 20.97}
# Iteration no: 11
# {'Time, Speed, Fuel, Distance': [0.97, 18, 2, 0], 'Cost': 20.97}
# Iteration no: 12
# {'Time, Speed, Fuel, Distance': [0.97, 18, 2, 0], 'Cost': 20.97}
# Iteration no: 13
# {'Time, Speed, Fuel, Distance': [0.97, 18, 2, 0], 'Cost': 20.97}
# Iteration no: 14
# {'Time, Speed, Fuel, Distance': [0.97, 18, 2, 0], 'Cost': 20.97}
# Iteration no: 15
# {'Time, Speed, Fuel, Distance': [0.97, 18, 2, 0], 'Cost': 20.97}
# Iteration no: 16
# {'Time, Speed, Fuel, Distance': [0.97, 18, 2, 0], 'Cost': 20.97}
# Iteration no: 17
# {'Time, Speed, Fuel, Distance': [0.97, 18, 2, 0], 'Cost': 20.97}
# Iteration no: 18
# {'Time, Speed, Fuel, Distance': [0.97, 18, 2, 0], 'Cost': 20.97}
# Iteration no: 19
# {'Time, Speed, Fuel, Distance': [0.97, 18, 2, 0], 'Cost': 20.97}
# Iteration no: 20
# {'Time, Speed, Fuel, Distance': [0.97, 18, 2, 0], 'Cost': 20.97}
# Iteration no: 21
# {'Time, Speed, Fuel, Distance': [0.97, 18, 2, 0], 'Cost': 20.97}
# Iteration no: 22
# {'Time, Speed, Fuel, Distance': [0.97, 18, 2, 0], 'Cost': 20.97}
# Iteration no: 23
# {'Time, Speed, Fuel, Distance': [0.97, 18, 2, 0], 'Cost': 20.97}
# Iteration no: 24
# {'Time, Speed, Fuel, Distance': [0.97, 18, 2, 0], 'Cost': 20.97}
# Iteration no: 25
# {'Time, Speed, Fuel, Distance': [0.97, 18, 2, 0], 'Cost': 20.97}
# Iteration no: 26
# {'Time, Speed, Fuel, Distance': [0.97, 18, 2, 0], 'Cost': 20.97}
# Iteration no: 27
# {'Time, Speed, Fuel, Distance': [0.97, 18, 2, 0], 'Cost': 20.97}
# Iteration no: 28
# {'Time, Speed, Fuel, Distance': [0.97, 18, 2, 0], 'Cost': 20.97}
# Iteration no: 29
# {'Time, Speed, Fuel, Distance': [0.97, 18, 2, 0], 'Cost': 20.97}
# Iteration no: 30
# {'Time, Speed, Fuel, Distance': [0.97, 18, 2, 0], 'Cost': 20.97}
# Iteration no: 31
# {'Time, Speed, Fuel, Distance': [0.97, 18, 2, 0], 'Cost': 20.97}
# Iteration no: 32
# {'Time, Speed, Fuel, Distance': [0.97, 18, 2, 0], 'Cost': 20.97}
# Iteration no: 33
# {'Time, Speed, Fuel, Distance': [0.97, 18, 2, 0], 'Cost': 20.97}
# Iteration no: 34
# {'Time, Speed, Fuel, Distance': [0.97, 18, 2, 0], 'Cost': 20.97}
# Iteration no: 35
# {'Time, Speed, Fuel, Distance': [0.97, 18, 2, 0], 'Cost': 20.97}
# Iteration no: 36
# {'Time, Speed, Fuel, Distance': [0.97, 18, 2, 0], 'Cost': 20.97}
# Iteration no: 37
# {'Time, Speed, Fuel, Distance': [0.97, 18, 2, 0], 'Cost': 20.97}
# Iteration no: 38
# {'Time, Speed, Fuel, Distance': [0.97, 18, 2, 0], 'Cost': 20.97}
# Iteration no: 39
# {'Time, Speed, Fuel, Distance': [0.97, 18, 2, 0], 'Cost': 20.97}
# Iteration no: 40
# {'Time, Speed, Fuel, Distance': [0.97, 18, 2, 0], 'Cost': 20.97}
# Iteration no: 41
# {'Time, Speed, Fuel, Distance': [0.97, 18, 2, 0], 'Cost': 20.97}
# Iteration no: 42
# {'Time, Speed, Fuel, Distance': [0.97, 18, 2, 0], 'Cost': 20.97}
# Iteration no: 43
# {'Time, Speed, Fuel, Distance': [0.97, 18, 2, 0], 'Cost': 20.97}
# Iteration no: 44
# {'Time, Speed, Fuel, Distance': [0.97, 18, 2, 0], 'Cost': 20.97}
# Iteration no: 45
# {'Time, Speed, Fuel, Distance': [0.97, 18, 2, 0], 'Cost': 20.97}
# Iteration no: 46
# {'Time, Speed, Fuel, Distance': [0.97, 18, 2, 0], 'Cost': 20.97}
# Iteration no: 47
# {'Time, Speed, Fuel, Distance': [0.97, 18, 2, 0], 'Cost': 20.97}
# Iteration no: 48
# {'Time, Speed, Fuel, Distance': [0.35, 18, 2, 0], 'Cost': 20.35}
# Iteration no: 49
# {'Time, Speed, Fuel, Distance': [0.35, 18, 2, 0], 'Cost': 20.35}
# Iteration no: 50
# {'Time, Speed, Fuel, Distance': [0.35, 18, 2, 0], 'Cost': 20.35}
# Iteration no: 51
# {'Time, Speed, Fuel, Distance': [0.1, 11, 9, 0], 'Cost': 20.1}
# Iteration no: 52
# {'Time, Speed, Fuel, Distance': [0.1, 11, 9, 0], 'Cost': 20.1}
# Iteration no: 53
# {'Time, Speed, Fuel, Distance': [0.1, 11, 9, 0], 'Cost': 20.1}
# Iteration no: 54
# {'Time, Speed, Fuel, Distance': [0.1, 11, 9, 0], 'Cost': 20.1}
# Iteration no: 55
# {'Time, Speed, Fuel, Distance': [0.1, 11, 9, 0], 'Cost': 20.1}
# Iteration no: 56
# {'Time, Speed, Fuel, Distance': [0.1, 11, 9, 0], 'Cost': 20.1}
# Iteration no: 57
# {'Time, Speed, Fuel, Distance': [0.1, 11, 9, 0], 'Cost': 20.1}
# Iteration no: 58
# {'Time, Speed, Fuel, Distance': [0.1, 11, 9, 0], 'Cost': 20.1}
# Iteration no: 59
# {'Time, Speed, Fuel, Distance': [0.1, 11, 9, 0], 'Cost': 20.1}
# Iteration no: 60
# {'Time, Speed, Fuel, Distance': [0.1, 11, 9, 0], 'Cost': 20.1}
# Iteration no: 61
# {'Time, Speed, Fuel, Distance': [0.1, 11, 9, 0], 'Cost': 20.1}
# Iteration no: 62
# {'Time, Speed, Fuel, Distance': [0.1, 11, 9, 0], 'Cost': 20.1}
# Iteration no: 63
# {'Time, Speed, Fuel, Distance': [0.1, 11, 9, 0], 'Cost': 20.1}
# Iteration no: 64
# {'Time, Speed, Fuel, Distance': [0.1, 11, 9, 0], 'Cost': 20.1}
# Iteration no: 65
# {'Time, Speed, Fuel, Distance': [0.1, 11, 9, 0], 'Cost': 20.1}
# Iteration no: 66
# {'Time, Speed, Fuel, Distance': [0.1, 11, 9, 0], 'Cost': 20.1}
# Iteration no: 67
# {'Time, Speed, Fuel, Distance': [0.1, 11, 9, 0], 'Cost': 20.1}
# Iteration no: 68
# {'Time, Speed, Fuel, Distance': [0.1, 11, 9, 0], 'Cost': 20.1}
# Iteration no: 69
# {'Time, Speed, Fuel, Distance': [0.1, 11, 9, 0], 'Cost': 20.1}
# Iteration no: 70
# {'Time, Speed, Fuel, Distance': [0.1, 11, 9, 0], 'Cost': 20.1}
# Iteration no: 71
# {'Time, Speed, Fuel, Distance': [0.1, 11, 9, 0], 'Cost': 20.1}
# Iteration no: 72
# {'Time, Speed, Fuel, Distance': [0.1, 11, 9, 0], 'Cost': 20.1}
# Iteration no: 73
# {'Time, Speed, Fuel, Distance': [0.1, 11, 9, 0], 'Cost': 20.1}
# Iteration no: 74
# {'Time, Speed, Fuel, Distance': [0.1, 11, 9, 0], 'Cost': 20.1}
# Iteration no: 75
# {'Time, Speed, Fuel, Distance': [0.1, 11, 9, 0], 'Cost': 20.1}
# Iteration no: 76
# {'Time, Speed, Fuel, Distance': [0.1, 11, 9, 0], 'Cost': 20.1}
# Iteration no: 77
# {'Time, Speed, Fuel, Distance': [0.1, 11, 9, 0], 'Cost': 20.1}
# Iteration no: 78
# {'Time, Speed, Fuel, Distance': [0.1, 11, 9, 0], 'Cost': 20.1}
# Iteration no: 79
# {'Time, Speed, Fuel, Distance': [0.1, 11, 9, 0], 'Cost': 20.1}
# Iteration no: 80
# {'Time, Speed, Fuel, Distance': [0.1, 11, 9, 0], 'Cost': 20.1}
# Iteration no: 81
# {'Time, Speed, Fuel, Distance': [0.1, 11, 9, 0], 'Cost': 20.1}
# Iteration no: 82
# {'Time, Speed, Fuel, Distance': [0.1, 11, 9, 0], 'Cost': 20.1}
# Iteration no: 83
# {'Time, Speed, Fuel, Distance': [0.1, 11, 9, 0], 'Cost': 20.1}
# Iteration no: 84
# {'Time, Speed, Fuel, Distance': [0.1, 11, 9, 0], 'Cost': 20.1}
# Iteration no: 85
# {'Time, Speed, Fuel, Distance': [0.1, 11, 9, 0], 'Cost': 20.1}
# Iteration no: 86
# {'Time, Speed, Fuel, Distance': [0.1, 11, 9, 0], 'Cost': 20.1}
# Iteration no: 87
# {'Time, Speed, Fuel, Distance': [0.1, 11, 9, 0], 'Cost': 20.1}
# Iteration no: 88
# {'Time, Speed, Fuel, Distance': [0.1, 11, 9, 0], 'Cost': 20.1}
# Iteration no: 89
# {'Time, Speed, Fuel, Distance': [0.1, 11, 9, 0], 'Cost': 20.1}
# Iteration no: 90
# {'Time, Speed, Fuel, Distance': [0.1, 11, 9, 0], 'Cost': 20.1}
# Iteration no: 91
# {'Time, Speed, Fuel, Distance': [0.1, 11, 9, 0], 'Cost': 20.1}
# Iteration no: 92
# {'Time, Speed, Fuel, Distance': [0.1, 11, 9, 0], 'Cost': 20.1}
# Iteration no: 93
# {'Time, Speed, Fuel, Distance': [0.1, 11, 9, 0], 'Cost': 20.1}
# Iteration no: 94
# {'Time, Speed, Fuel, Distance': [0.1, 11, 9, 0], 'Cost': 20.1}
# Iteration no: 95
# {'Time, Speed, Fuel, Distance': [0.1, 11, 9, 0], 'Cost': 20.1}
# Iteration no: 96
# {'Time, Speed, Fuel, Distance': [0.1, 11, 9, 0], 'Cost': 20.1}
# Iteration no: 97
# {'Time, Speed, Fuel, Distance': [0.1, 11, 9, 0], 'Cost': 20.1}
# Iteration no: 98
# {'Time, Speed, Fuel, Distance': [0.1, 11, 9, 0], 'Cost': 20.1}
# Iteration no: 99
# Solution
# 0.1  Hrs  11  Km/Hr  9 Litres 0 Kms
# Cost20.1
